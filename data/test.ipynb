# %%
import numpy as np
data = np.load('iam/lines/labels.pkl', allow_pickle=True)
print(data)
# Out:
# {'ground_truth': {'train': {'train_0.png': {'text': 'A ROYAL welcome for the Kabaka of'}, 'train_1.png': {'text': 'insensitively pushing, Miss Sheila Allen'}, 'train_2.png': {'text': 'method known as homoeopathy had been'}, 'train_3.png': {'text': 'With fire and sword France denies Algeria the right to self-'}, 'train_4.png': {'text': 'And so they prefer objective methods. Since they cannot'}, 'train_5.png': {'text': 'doubtless continue, for it is the aim of science to'}, 'train_6.png': {'text': 'rearmament policy. Hopes rose as we saw a'}, 'train_7.png': {'text': 'clearly, sections of the movement reaffirmed their'}, 'train_8.png': {'text': 'Mr Gaitskell said that a member of an alliance could'}, 'train_9.png': {'text': 'was far better for a weapon used for retaliatory'}, 'train_10.png': {'text': 'Happy patrolling, Mr. Finlay!'}, 'train_11.png': {'text': 'of Staff, a process that may take four'}, 'train_12.png': {'text': 'a new Conservative booklet called The Record Speaks'}, 'train
# ...
